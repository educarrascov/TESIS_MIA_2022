# %% [markdown]
# # Sistema Multi-Agente Centralizado para Actividades de Monitoreo <img src="logo.png" align="right" width = "95px"/>
#
# Alumnnos:
#     - Eduardo Carrasco.
#     - Argenis Chirinos.
#     - Gustavo Jara.
#
# Profesor Guía: Enrique Canessa. Facultad de Ingeniería y Ciencias, UAI.
#
# ![Python](https://img.shields.io/badge/python-%2314354C.svg)![GitHub](https://img.shields.io/badge/github-%23121011.svg)

# %% [markdown]
# # Descripción del modelo:
#
# Si tomamos la condición actual (con uso de bote) como un modelo previo (**antes**), e implementamos un modelo con drones (**despues**). Para poder decidir sí a la implementación del modelo, se selecciona los TMI obtenidos de la simuñación de ambos modelos, con uso de botes y con uso de drones.
# En vista de los datos obtenidos ¿Hay diferencia significativa entre el rendimiento de ambos modelos?

# %% [markdown]
# ## Hipótesis
#
# - 𝐻0 : no hay diferencia entre el tiempo medio entre el modelo de botes y el modelo de drones. El promedio de las diferencias es cero ( 𝜇𝑑=0 ).
# - 𝐻𝑎 : sí hay diferencia entre el tiempo medio entre el modelo de botes y el modelo de drones. El promedio de las diferencias no es cero ( 𝜇𝑑≠0 ).

# %% [markdown]
# ## Estadístico observado
#
# El estadístico es el valor que se calcula a partir de la muestra y que se quiere extrapolar a la población de origen. En este caso, es el promedio de las diferencias entre cada par de observaciones  𝑑⎯⎯⎯=−0.5 .

# %%
pip install pingouin
# Out:
# Collecting pingouin
#   Downloading pingouin-0.5.2.tar.gz (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (1.21.5)
# Requirement already satisfied: scipy>=1.7 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (1.9.1)
# Requirement already satisfied: pandas>=1.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (1.4.4)
# Requirement already satisfied: matplotlib>=3.0.2 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (3.5.2)
# Requirement already satisfied: seaborn>=0.11 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (0.11.2)
# Requirement already satisfied: statsmodels>=0.13 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (0.13.2)
# Requirement already satisfied: scikit-learn<1.1.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (1.0.2)
# Collecting pandas_flavor>=0.2.0
#   Downloading pandas_flavor-0.3.0-py3-none-any.whl (6.3 kB)
# Collecting outdated
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: tabulate in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pingouin) (0.8.10)
# Requirement already satisfied: cycler>=0.10 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.2->pingouin) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->pingouin) (2022.1)
# Requirement already satisfied: xarray in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from pandas_flavor>=0.2.0->pingouin) (0.20.1)
# Collecting lazy-loader==0.1rc2
#   Downloading lazy_loader-0.1rc2-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.1.0->pingouin) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn<1.1.0->pingouin) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13->pingouin) (0.5.2)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=44 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from outdated->pingouin) (63.4.1)
# Requirement already satisfied: requests in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from outdated->pingouin) (2.28.1)
# Requirement already satisfied: six in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13->pingouin) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from requests->outdated->pingouin) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from requests->outdated->pingouin) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from requests->outdated->pingouin) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/educarrascovidal/opt/anaconda3/lib/python3.9/site-packages (from requests->outdated->pingouin) (1.26.11)
# Building wheels for collected packages: pingouin, littleutils
#   Building wheel for pingouin (setup.py) ... done
#   Created wheel for pingouin: filename=pingouin-0.5.2-py3-none-any.whl size=196190 sha256=145c3b648e0874fb07c02ab8cc4d7787bbffc1df41f821a225f8e2d71dc2eb44
#   Stored in directory: /Users/educarrascovidal/Library/Caches/pip/wheels/c0/9f/92/4c574395e1e8e5e08cf73dcb76815a7eaa62921833b6b0f6ad
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7028 sha256=7388b220f3fd87f56c1ba94ccc297080cc6cf28f49af892c6a5b4a9308b98fd6
#   Stored in directory: /Users/educarrascovidal/Library/Caches/pip/wheels/04/bb/0d/2d02ec45f29c48d6192476bfb59c5a0e64b605e7212374dd15
# Successfully built pingouin littleutils
# Installing collected packages: littleutils, lazy-loader, outdated, pandas_flavor, pingouin
# Successfully installed lazy-loader-0.1rc2 littleutils-0.2.2 outdated-0.2.2 pandas_flavor-0.3.0 pingouin-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import pingouin as pg

# %%
datos_drones = pd.read_csv('Drones.csv', sep=';', decimal=",")
datos_drones.rename(columns = {'TMI':'TMI_despues'}, inplace = True)
datos_drone_2 = datos_drones.iloc[0:30,:]
print(datos_drone_2)
# Out:
#     Embarcaciones  Drones  Prob. de falla  TMI_despues
# 0              15       1             0.0       133.87
# 1              15       1             0.0       101.60
# 2              15       1             0.0        99.80
# 3              15       1             0.0       122.27
# 4              15       1             0.0       123.13
# 5              15       1             0.0       101.93
# 6              15       1             0.0       136.20
# 7              15       1             0.0       126.20
# 8              15       1             0.0       105.27
# 9              15       1             0.0       106.53
# 10             15       1             0.0       114.40
# 11             15       1             0.0        92.40
# 12             15       1             0.0       102.47
# 13             15       1             0.0       112.67
# 14             15       1             0.0        82.93
# 15             15       1             0.0       127.67
# 16             15       1             0.0        89.53
# 17             15       1             0.0       116.47
# 18             15       1             0.0       136.20
# 19             15       1             0.0       139.33
# 20             15       1             0.0        88.20
# 21             15       1             0.0       115.47
# 22             15       1             0.0       104.80
# 23             15       1             0.0       118.80
# 24             15       1             0.0       108.60
# 25             15       1             0.0        94.20
# 26             15       1             0.0       133.80
# 27             15       1             0.0        95.60
# 28             15       1             0.0        99.27
# 29             15       1             0.0       120.80

# %%
datos_bote = pd.read_csv('Bote2.csv', sep=';', decimal=",")
datos_bote.rename(columns = {'TMI':'TMI_antes'}, inplace = True)
datos_bote_2 = datos_bote.iloc[0:30,:]
print(datos_bote_2)
# Out:
#     Embarcaciones  Botes  Tiempo de navegacion  TMI_antes
# 0              15      1                  2220     148.00
# 1              15      1                  4275     285.00
# 2              15      1                  5093     339.53
# 3              15      1                  2943     196.20
# 4              15      1                  6297     419.80
# 5              15      1                  6407     427.13
# 6              15      1                  4294     286.27
# 7              15      1                  4136     275.73
# 8              15      1                  3594     239.60
# 9              15      1                  6134     408.93
# 10             15      1                  7724     514.93
# 11             15      1                  4171     278.07
# 12             15      1                  5779     385.27
# 13             15      1                  4764     317.60
# 14             15      1                  3203     213.53
# 15             15      1                  3036     202.40
# 16             15      1                  3652     243.47
# 17             15      1                  4340     289.33
# 18             15      1                  4343     289.53
# 19             15      1                  7063     470.87
# 20             15      1                  4052     270.13
# 21             15      1                  3685     245.67
# 22             15      1                  5385     359.00
# 23             15      1                  3241     216.07
# 24             15      1                  3253     216.87
# 25             15      1                  7555     503.67
# 26             15      1                  4295     286.33
# 27             15      1                  4239     282.60
# 28             15      1                  3731     248.73
# 29             15      1                  5335     355.67

# %%
datos = pd.concat([datos_bote_2, datos_drone_2], axis=1)
display(datos)
# Out:
#     Embarcaciones  Botes  Tiempo de navegacion  TMI_antes  Embarcaciones  \
# 0              15      1                  2220     148.00             15
# 1              15      1                  4275     285.00             15
# 2              15      1                  5093     339.53             15
# 3              15      1                  2943     196.20             15
# 4              15      1                  6297     419.80             15
# 5              15      1                  6407     427.13             15
# 6              15      1                  4294     286.27             15
# 7              15      1                  4136     275.73             15
# 8              15      1                  3594     239.60             15
# 9              15      1                  6134     408.93             15
# 10             15      1                  7724     514.93             15
# 11             15      1                  4171     278.07             15
# 12             15      1                  5779     385.27             15
# 13             15      1                  4764     317.60             15
# 14             15      1                  3203     213.53             15
# 15             15      1                  3036     202.40             15
# 16             15      1                  3652     243.47             15
# 17             15      1                  4340     289.33             15
# 18             15      1                  4343     289.53             15
# 19             15      1                  7063     470.87             15
# 20             15      1                  4052     270.13             15
# 21             15      1                  3685     245.67             15
# 22             15      1                  5385     359.00             15
# 23             15      1                  3241     216.07             15
# 24             15      1                  3253     216.87             15
# 25             15      1                  7555     503.67             15
# 26             15      1                  4295     286.33             15
# 27             15      1                  4239     282.60             15
# 28             15      1                  3731     248.73             15
# 29             15      1                  5335     355.67             15
#
#     Drones  Prob. de falla  TMI_despues
# 0        1             0.0       133.87
# 1        1             0.0       101.60
# 2        1             0.0        99.80
# 3        1             0.0       122.27
# 4        1             0.0       123.13
# 5        1             0.0       101.93
# 6        1             0.0       136.20
# 7        1             0.0       126.20
# 8        1             0.0       105.27
# 9        1             0.0       106.53
# 10       1             0.0       114.40
# 11       1             0.0        92.40
# 12       1             0.0       102.47
# 13       1             0.0       112.67
# 14       1             0.0        82.93
# 15       1             0.0       127.67
# 16       1             0.0        89.53
# 17       1             0.0       116.47
# 18       1             0.0       136.20
# 19       1             0.0       139.33
# 20       1             0.0        88.20
# 21       1             0.0       115.47
# 22       1             0.0       104.80
# 23       1             0.0       118.80
# 24       1             0.0       108.60
# 25       1             0.0        94.20
# 26       1             0.0       133.80
# 27       1             0.0        95.60
# 28       1             0.0        99.27
# 29       1             0.0       120.80

# %%
# ingresar la desviación standar y la media  de ambos valores (antes y después).
datos.iloc[:,3].describe() #observamos las desviaciones estandar
# Out:
# count     30.000000
# mean     307.197667
# std       93.545326
# min      148.000000
# 25%      244.020000
# 50%      285.635000
# 75%      358.167500
# max      514.930000
# Name: TMI_antes, dtype: float64

# %%
datos.iloc[:,7].describe() #observamos las desviaciones estandar
# Out:
# count     30.000000
# mean     111.680333
# std       15.912896
# min       82.930000
# 25%      100.250000
# 50%      110.635000
# 75%      122.915000
# max      139.330000
# Name: TMI_despues, dtype: float64

# %% [markdown]
# Al tratarse de datos pareados, interesa conocer la diferencia.

# %%
datos['diferencia'] = datos['TMI_antes'] - datos['TMI_despues']
datos.head(10)
# Out:
#    Embarcaciones  Botes  Tiempo de navegacion  TMI_antes  Embarcaciones  \
# 0             15      1                  2220     148.00             15
# 1             15      1                  4275     285.00             15
# 2             15      1                  5093     339.53             15
# 3             15      1                  2943     196.20             15
# 4             15      1                  6297     419.80             15
# 5             15      1                  6407     427.13             15
# 6             15      1                  4294     286.27             15
# 7             15      1                  4136     275.73             15
# 8             15      1                  3594     239.60             15
# 9             15      1                  6134     408.93             15
#
#    Drones  Prob. de falla  TMI_despues  diferencia
# 0       1             0.0       133.87       14.13
# 1       1             0.0       101.60      183.40
# 2       1             0.0        99.80      239.73
# 3       1             0.0       122.27       73.93
# 4       1             0.0       123.13      296.67
# 5       1             0.0       101.93      325.20
# 6       1             0.0       136.20      150.07
# 7       1             0.0       126.20      149.53
# 8       1             0.0       105.27      134.33
# 9       1             0.0       106.53      302.40

# %%
datos['diferencia'].describe()
# Out:
# count     30.000000
# mean     195.517333
# std       95.388711
# min       14.130000
# 25%      138.112500
# 50%      177.395000
# 75%      250.582500
# max      409.470000
# Name: diferencia, dtype: float64

# %%
# Gráficos de distribución
# ==============================================================================
fig, axs = plt.subplots(2, 2, figsize=(12, 7))

# Valores de la media (mu) y desviación típica (sigma)
mu, sigma = stats.norm.fit(datos['TMI_antes'])

# Valores teóricos de la normal en el rango observado
x_hat = np.linspace(min(datos['TMI_antes']), max(datos['TMI_antes']), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)

# Gráfico distribución
axs[0, 0].plot(x_hat, y_hat, linewidth=2, label='normal')
axs[0, 0].hist(x=datos['TMI_antes'], density=True, bins=20, color="#3182bd", alpha=0.5)
axs[0, 0].plot(datos['TMI_antes'], np.full_like(datos['TMI_antes'], -0.0), '|k', markeredgewidth=1)
axs[0, 0].set_title('Distribución usando Botes')
axs[0, 0].set_xlabel('tiempo')
axs[0, 0].set_ylabel('Densidad de probabilidad')
axs[0, 0].legend()

# Gráfico distribución qq-plot
pg.qqplot(datos['TMI_antes'], dist='norm', ax=axs[0, 1])

mu, sigma = stats.norm.fit(datos['TMI_despues'])
x_hat = np.linspace(min(datos['TMI_despues']), max(datos['TMI_despues']), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)
axs[1, 0].plot(x_hat, y_hat, linewidth=2, label='normal')
axs[1, 0].hist(x=datos['TMI_despues'], density=True, bins=20, color="#3182bd", alpha=0.5)
axs[1, 0].plot(datos['TMI_despues'], np.full_like(datos['TMI_despues'], -0.0), '|k', markeredgewidth=1)
axs[1, 0].set_title('Distribución usando Drones')
axs[1, 0].set_xlabel('tiempo')
axs[1, 0].set_ylabel('Densidad de probabilidad')
axs[1, 0].legend()

pg.qqplot(datos['TMI_despues'], dist='norm', ax=axs[1, 1])
plt.tight_layout();

# %%
# Test de normalidad Shapiro-Wilk aplicado a sistema de botes
# ==============================================================================
pg.normality(data=datos['TMI_antes'])
# Out:
#                   W      pval  normal
# TMI_antes  0.937475  0.077789    True

# %% [markdown]
# De acuerdo al resultado obtenido, los datos obtenidos no se distribuyen normalmente.

# %%
# Test de normalidad Shapiro-Wilk aplicado a sistema de drones
# ==============================================================================
pg.normality(data=datos['TMI_despues'])
# Out:
#                     W     pval  normal
# TMI_despues  0.966104  0.43875    True

# %% [markdown]
# De acuerdo al resultado obtenido, los datos no se distribuyen normalmente.

# %%
# Test para datos dependientes (p-value, intervalos de confianza)
# ==============================================================================

pg.ttest(
    x           = datos['TMI_antes'],
    y           = datos['TMI_despues'],
    alternative = 'two-sided',
    paired      = True,
    correction  = False
)
# Out:
#                 T  dof alternative         p-val            CI95%   cohen-d  \
# T-test  11.226617   29   two-sided  4.490120e-12  [159.9, 231.14]  2.913961
#
#              BF10  power
# T-test  1.906e+09    1.0

# %% [markdown]
# **El p-value obtenido por el t-test pareado es inferior al nivel de significancia establecido** ( 𝑎𝑙𝑝ℎ𝑎=0.05 ), por lo cual, se rechaza la hipótesis nula en favor de la hipótesis alternativa, esto quiere decir que el rendimiento del modelo ha cambiado (mejorado).
